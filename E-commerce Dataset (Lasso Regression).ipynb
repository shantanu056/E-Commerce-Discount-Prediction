# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

import warnings                    
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("Ecommerce_Cleaned_Data.xlsx")
df
# Out:
#       Category   Price  Discount  Final_Price  Payment_Method
# 0            5   36.53        15        31.05               3
# 1            2  232.79        20       186.23               3
# 2            5  317.02        25       237.76               1
# 3            6  173.19        25       129.89               4
# 4            0  244.80        20       195.84               3
# ...        ...     ...       ...          ...             ...
# 3655         0  486.79         0       486.79               4
# 3656         6  212.87        15       180.94               0
# 3657         4  389.76         0       389.76               3
# 3658         3  447.66        30       313.36               4
# 3659         4  235.77        30       165.04               4
#
# [3660 rows x 5 columns]

# %% [markdown]
# **Data Modelling**

# %%
X = df.drop(columns='Discount')
y = df['Discount']

# %% [markdown]
# **Train-Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=10 )

# %% [markdown]
# **Modelling(Lasso)**

# %%
from sklearn.linear_model import Lasso

lasso_base = Lasso()
lasso_base.fit(X_train, y_train)
# Out:
# Lasso()

# %% [markdown]
# **Predictions**

# %%
train_predictions = lasso_base.predict(X_train)
test_predictions = lasso_base.predict(X_test)

# %% [markdown]
# **Evaluation**

# %%
print("Train R2:", lasso_base.score(X_train, y_train))
print("Test R2:", lasso_base.score(X_test, y_test))

from sklearn.model_selection import cross_val_score
print("Cross Validation Score:", cross_val_score(lasso_base, X, y, cv=5).mean())
# Out:
# Train R2: 0.7631239092528812
# Test R2: 0.7639728376926717
# Cross Validation Score: 0.7632346884734963

# %% [markdown]
# **Hyperparameter Tuning**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso

# Model
estimator = Lasso()

# Parameters & values
param_grid = {"alpha": [0.1, 0.2, 0.5, 0.7, 1, 10, 50, 100, 1000]}

# Identifying the best value of the parameter within given values for the given data
model_hp = GridSearchCV(estimator, param_grid, cv=5, scoring='neg_mean_squared_error')
model_hp.fit(X_train, y_train)

# Displaying the best parameters
model_hp.best_params_
# Out:
# {'alpha': 0.5}

# %% [markdown]
# **Rebuilding model with ideal parameter**

# %%
# Modelling
from sklearn.linear_model import Lasso

lasso_best = Lasso(alpha=0.5)
lasso_best.fit(X_train, y_train)

# Predictions
train_predictions = lasso_best.predict(X_train)
test_predictions = lasso_best.predict(X_test)

# Evaluation
from sklearn.model_selection import cross_val_score

print("Train R2:", lasso_best.score(X_train, y_train))
print("Test R2:", lasso_best.score(X_test, y_test))
print("Cross Validation Score:", cross_val_score(lasso_best, X, y, cv=5).mean())
# Out:
# Train R2: 0.7631300478055127
# Test R2: 0.7640769211231222
# Cross Validation Score: 0.763240272842711
